# %% [markdown]
# <a href="https://colab.research.google.com/github/castrorafa/Covid-19-Estados-Brasil/blob/main/covid-19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings("ignore")

import os
import numpy as np
import pandas as pd

# %%
estados = 'AC', 'AL', 'AM', 'AP', 'BA', 'CE', 'DF', 'ES', 'GO', 'MA', 'MG', 'MS', 'MT', 'PA', 'PB', 'PE', 'PI', 'PR', 'RJ', 'RN', 'RO', 'RR', 'RS', 'SC', 'SE', 'SP', 'TO'

# %%
dadosuf = pd.read_excel('/content/drive/MyDrive/DataScience/estimativa_dou_2025.xls', header=1)
dadosuf = dadosuf.drop('Unnamed: 2', axis=1)
dadosuf.head()
# Out:
#   BRASIL E UNIDADES DA FEDERAÇÃO  POPULAÇÃO ESTIMADA
# 0                         Brasil         213421037.0
# 1                          Norte          18801282.0
# 2                       Rondônia           1751950.0
# 3                           Acre            884372.0
# 4                       Amazonas           4321616.0

# %%
habuf = dadosuf.copy()
habuf.rename(columns={'BRASIL E UNIDADES DA FEDERAÇÃO':'UF', 'POPULAÇÃO ESTIMADA':'Populacao'}, inplace=True)
linhas_remover = [0, 1, 9, 19, 24, 28, 33, 34, 35, 36]
habuf = habuf.drop(linhas_remover)
habuf = habuf.sort_values(by='UF')
habuf = habuf.reset_index()
habuf = habuf.drop('index', axis=1)
habuf['Populacao'] = habuf['Populacao'].astype(int)
habuf.head()
# Out:
#          UF  Populacao
# 0      Acre     884372
# 1   Alagoas    3220848
# 2     Amapá     806517
# 3  Amazonas    4321616
# 4     Bahia   14870907

# %%
#Lendo múltiplos arquivos de um diretório.
diretorio = '/content/drive/MyDrive/DataScience/Covid-DadosBrasil'
covid_brasil = []
for nome_arquivo in os.listdir(diretorio):
  if nome_arquivo.endswith('.csv'):
    caminho_completo = os.path.join(diretorio, nome_arquivo)
    df = pd.read_csv(caminho_completo)
    covid_brasil.append(df)

# %%
#Concatenando Dataframes
covid_completo = pd.concat(covid_brasil, axis=1)
covid_completo.head()
# Out:
#     Ano  Casos Novos   Ano  Casos Novos   Ano  Casos Novos   Ano  Casos Novos  \
# 0  2020        41620  2020       104818  2020       201013  2020        68201
# 1  2021        46764  2021       137262  2021       232800  2021        58780
# 2  2022        70285  2022        93096  2022       191051  2022        55535
# 3  2023         7376  2023         8410  2023        13821  2023         4309
# 4  2024         3848  2024         5384  2024         5146  2024         5086
#
#     Ano  Casos Novos  ...   Ano  Casos Novos   Ano  Casos Novos   Ano  \
# 0  2020       493400  ...  2020       449674  2020       492583  2020
# 1  2021       777458  ...  2021      1057443  2021       750952  2021
# 2  2022       498205  ...  2022      1388454  2022       712618  2022
# 3  2023        54680  ...  2023       194191  2023       100731  2023
# 4  2024        23499  ...  2024        67299  2024        39339  2024
#
#    Casos Novos   Ano  Casos Novos   Ano  Casos Novos
# 0       112505  2020      1462297  2020        90358
# 1       166025  2021      2993811  2021       145200
# 2        79751  2022      1859225  2022       124009
# 3         7174  2023       447977  2023        13073
# 4         2760  2024       153769  2024         9789
#
# [5 rows x 54 columns]

# %%
# Colocando a coluna 'Ano' como índice e colocando os nomes dos estados como cabeçalho.
ano_col = covid_completo.filter(like='Ano').iloc[:, 0]
casos_novos_col = covid_completo.filter(like='Casos Novos')
covid_final = pd.DataFrame(casos_novos_col.values, index=ano_col)
covid_final.columns = estados
covid_final.head()
# Out:
#          AC      AL      AM     AP      BA      CE      DF      ES      GO  \
# Ano
# 2020  41620  104818  201013  68201  493400  335091  251701  248232  308868
# 2021  46764  137262  232800  58780  777458  621234  268110  381639  638836
# 2022  70285   93096  191051  55535  498205  480846  368252  681273  876276
# 2023   7376    8410   13821   4309   54680   54483   39157   49728  160694
# 2024   3848    5384    5146   5086   23499   26371   29287   28250   75844
#
#           MA  ...       PR       RJ      RN      RO     RR       RS      SC  \
# Ano           ...
# 2020  200938  ...   416566   434648  118083   95729  68689   449674  492583
# 2021  169707  ...  1181736   918176  269119  188897  60397  1057443  750952
# 2022  117448  ...  1262911  1348554  195416  187047  52159  1388454  712618
# 2023   10744  ...   118041   191241   13554   18617   5095   194191  100731
# 2024    2295  ...    58301    87704    5801   14821   4064    67299   39339
#
#           SE       SP      TO
# Ano
# 2020  112505  1462297   90358
# 2021  166025  2993811  145200
# 2022   79751  1859225  124009
# 2023    7174   447977   13073
# 2024    2760   153769    9789
#
# [5 rows x 27 columns]

# %%
#Mudando formato e renomeando colunas do Dataframe para facilitar a junção com o Dataframe com dados da população total de cada estado.
covid_casos = covid_final.reset_index().melt(id_vars='Ano', var_name='UF', value_name='Casos')
covid_casos.head()
# Out:
#     Ano  UF  Casos
# 0  2020  AC  41620
# 1  2021  AC  46764
# 2  2022  AC  70285
# 3  2023  AC   7376
# 4  2024  AC   3848

# %%
#Criando dicionário com o nome completo dos estados para substituir pela abreviação nos Dataframes.
estados_completo = dict(zip(estados, habuf['UF']))
covid_casos['UF'] = covid_casos['UF'].map(estados_completo)
covid_casos.head()
# Out:
#     Ano    UF  Casos
# 0  2020  Acre  41620
# 1  2021  Acre  46764
# 2  2022  Acre  70285
# 3  2023  Acre   7376
# 4  2024  Acre   3848

# %%
#Unindo os dois Dataframes.
covid_merged = pd.merge(covid_casos, habuf, on='UF')
covid_merged.head()
# Out:
#     Ano    UF  Casos  Populacao
# 0  2020  Acre  41620     884372
# 1  2021  Acre  46764     884372
# 2  2022  Acre  70285     884372
# 3  2023  Acre   7376     884372
# 4  2024  Acre   3848     884372

# %%
#Calculando taxa de contágio mudando a métrica para cada 100k habitantes.
covid_merged['Taxa(100k_Hab)'] = (covid_merged['Casos']/covid_merged['Populacao']*100000)
covid_merged['Taxa(100k_Hab)'] = covid_merged['Taxa(100k_Hab)'].astype(int)
covid_merged.head()
# Out:
#     Ano    UF  Casos  Populacao  Taxa(100k_Hab)
# 0  2020  Acre  41620     884372            4706
# 1  2021  Acre  46764     884372            5287
# 2  2022  Acre  70285     884372            7947
# 3  2023  Acre   7376     884372             834
# 4  2024  Acre   3848     884372             435

# %%
#Importando bibliotecas para gerar gráficos.
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
#Gráfico do número de casos de Covid-19 por estado, no período de 2020 a 2025.
fig = px.line(covid_final, x=covid_final.index, y=covid_final.columns, markers=True, labels={'variable':'Estados'})
fig.update_layout(width=1300, height=600, font_family='DejaVu Sans', font_size=15, title_font_size=24,
                  title_text='Número de casos de COVID-19 por estado' + '<br><sup size=1 style="color:#555655">De 2020 a 2025</sup>',
                  xaxis_title='', yaxis_title='', plot_bgcolor='whitesmoke')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1570a7fc-7d17-4983-8aa2-0f127c9d4884" class="plotly-graph-div" style="height:600px; width:1300px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1570a7fc-7d17-4983-8aa2-0f127c9d4884")) {                    Plotly.newPlot(                        "1570a7fc-7d17-4983-8aa2-0f127c9d4884",                        [{"hovertemplate":"Estados=AC\u003cbr\u003eAno=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AC","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"AC","orientation":"v","showlegend":true,"x":[2020,2021,2022,2023,2024,2025],"xaxis":"x","y":[41620,46764,70285,7376,3848,5084],"yaxis":"y","type":"scatter"},{"hovertemplate":"Estados=AL\u003cbr\u003eAno=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AL","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"AL","orientation":"v","showlegend":true,"x":[2020,2021,2022,2023,2024,2025],"xaxis":"x","y":[104818,137262,93096,8410,5384,2149],"yaxis":"y","type":"scatter"},{"hovertemplate":"Estados=AM\u003cbr\u003eAno=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AM","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"AM","orientation":"v","showlegend":true,"x":[2020,2021,2022,2023,2024,2025],"xaxis":"x","y":[201013,232800,191051,13821,5146,5787],"yaxis":"y","type":"scatter"},{"hovertemplate":"Estados=AP\u003cbr\u003eAno=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AP","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"AP","orientation":"v","showlegend":true,"x":[2020,2021,2022,2023,2024,2025],"xaxis":"x","y":[68201,58780,55535,4309,5086,2607],"yaxis":"y","type":"scatter"},{"hovertemplate":"Estados=BA\u003cbr\u003eAno=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BA","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"BA","orientation":"v","showlegend":true,"x":[2020,2021,2022,2023,2024,2025],"xaxis":"x","y":[493400,777458,498205,54680,23499,7120],"yaxis":"y","type":"scatter"},{"hovertemplate":"Estados=CE\u003cbr\u003eAno=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CE","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"CE","orientation":"v","showlegend":true,"x":[2020,2021,2022,2023,2024,2025],"xaxis":"x","y":[335091,621234,480846,54483,26371,18320],"yaxis":"y","type":"scatter"},{"hovertemplate":"Estados=DF\u003cbr\u003eAno=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DF","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"DF","orientation":"v","showlegend":true,"x":[2020,2021,2022,2023,2024,2025],"xaxis":"x","y":[251701,268110,368252,39157,29287,8796],"yaxis":"y","type":"scatter"},{"hovertemplate":"Estados=ES\u003cbr\u003eAno=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ES","line":{"color":"#B6E880","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"ES","orientation":"v","showlegend":true,"x":[2020,2021,2022,2023,2024,2025],"xaxis":"x","y":[248232,381639,681273,49728,28250,13869],"yaxis":"y","type":"scatter"},{"hovertemplate":"Estados=GO\u003cbr\u003eAno=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GO","line":{"color":"#FF97FF","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"GO","orientation" ...

# %%
#Criando dataframe com a taxa de contágio a cada 100 mil habitantes e com a porcentagem dessa mesma taxa.
covid_100k = covid_merged.copy()
covid_100k['Taxa(100k_Hab)'] = covid_100k['Taxa(100k_Hab)'].astype(int)
covid_100k['Taxa(%)'] = covid_100k['Taxa(100k_Hab)'] / 1000
covid_100k.head()
# Out:
#     Ano    UF  Casos  Populacao  Taxa(100k_Hab)  Taxa(%)
# 0  2020  Acre  41620     884372            4706    4.706
# 1  2021  Acre  46764     884372            5287    5.287
# 2  2022  Acre  70285     884372            7947    7.947
# 3  2023  Acre   7376     884372             834    0.834
# 4  2024  Acre   3848     884372             435    0.435

# %%
#Gráfico com a taxa de contágio de cada estado, em porcentagem a cada 100 mil habitantes.
fig = px.line(covid_100k, x='Ano', y='Taxa(%)', color='UF', markers=True, labels={'Taxa(%)':'Taxa de Contágio %', 'Ano':'Ano'})
fig.update_layout(width=1300, height=600, font_family='DejaVu Sans', font_size=15, title_font_size=24,
                  title='Evolução da Taxa de Contágio de COVID-19 por estado (por 100 mil habitantes)' +
                  '<br><sup size=1 style="color:#555655">De 2020 a 2025</sup>',
                  xaxis_title='',
                  yaxis_title='Taxa de Contágio %')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="01efe647-0741-4479-a774-8ca74a2446f6" class="plotly-graph-div" style="height:600px; width:1300px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("01efe647-0741-4479-a774-8ca74a2446f6")) {                    Plotly.newPlot(                        "01efe647-0741-4479-a774-8ca74a2446f6",                        [{"hovertemplate":"UF=Acre\u003cbr\u003eAno=%{x}\u003cbr\u003eTaxa de Contágio %=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Acre","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Acre","orientation":"v","showlegend":true,"x":[2020,2021,2022,2023,2024,2025],"xaxis":"x","y":[4.706,5.287,7.947,0.834,0.435,0.574],"yaxis":"y","type":"scatter"},{"hovertemplate":"UF=Alagoas\u003cbr\u003eAno=%{x}\u003cbr\u003eTaxa de Contágio %=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Alagoas","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Alagoas","orientation":"v","showlegend":true,"x":[2020,2021,2022,2023,2024,2025],"xaxis":"x","y":[3.254,4.261,2.89,0.261,0.167,0.066],"yaxis":"y","type":"scatter"},{"hovertemplate":"UF=Amapá\u003cbr\u003eAno=%{x}\u003cbr\u003eTaxa de Contágio %=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Amapá","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Amapá","orientation":"v","showlegend":true,"x":[2020,2021,2022,2023,2024,2025],"xaxis":"x","y":[24.923,28.864,23.688,1.713,0.638,0.717],"yaxis":"y","type":"scatter"},{"hovertemplate":"UF=Amazonas\u003cbr\u003eAno=%{x}\u003cbr\u003eTaxa de Contágio %=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Amazonas","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Amazonas","orientation":"v","showlegend":true,"x":[2020,2021,2022,2023,2024,2025],"xaxis":"x","y":[1.578,1.36,1.285,0.099,0.117,0.06],"yaxis":"y","type":"scatter"},{"hovertemplate":"UF=Bahia\u003cbr\u003eAno=%{x}\u003cbr\u003eTaxa de Contágio %=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bahia","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Bahia","orientation":"v","showlegend":true,"x":[2020,2021,2022,2023,2024,2025],"xaxis":"x","y":[3.317,5.228,3.35,0.367,0.158,0.047],"yaxis":"y","type":"scatter"},{"hovertemplate":"UF=Ceará\u003cbr\u003eAno=%{x}\u003cbr\u003eTaxa de Contágio %=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ceará","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Ceará","orientation":"v","showlegend":true,"x":[2020,2021,2022,2023,2024,2025],"xaxis":"x","y":[3.615,6.702,5.187,0.587,0.284,0.197],"yaxis":"y","type":"scatter"},{"hovertemplate":"UF=Distrito Federal\u003cbr\u003eAno=%{x}\u003cbr\u003eTaxa de Contágio %=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Distrito Federal","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Distrito Federal","orientation":"v","showlegend":true,"x":[2020,2021,2022,2023,2024,2025],"xaxis":"x","y":[8.398,8.946,12.287,1.306,0.977,0.293],"yaxis":"y","type":"scatter"},{"hovertemplate":"UF=Espírito Santo\u003cbr\u003eAno=%{x}\u003cbr\u003eTaxa de Contágio %=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Espírito Santo","line":{"color":"#B6E880","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Espírito Santo","orientation":"v","showlegend":true,"x":[2020,2021,2022,2023,2024,2025],"xaxis":"x","y":[6.015,9.247,16.508,1.204,0.684,0.336],"yaxis":"y","type":"scatter"},{"hovertemplate":"UF=Goiás\u003cbr\u003eAno=%{x}\ ...

# %%
cores = ['#003366', '#004780', '#005a99', '#006cb3', '#007fcc', '#0092e6', '#00a6ff', '#33b9ff', '#66ceff', '#99e3ff']

# %%
sns.color_palette("Paired")
# Out:
# [(0.6509803921568628, 0.807843137254902, 0.8901960784313725),
#  (0.12156862745098039, 0.47058823529411764, 0.7058823529411765),
#  (0.6980392156862745, 0.8745098039215686, 0.5411764705882353),
#  (0.2, 0.6274509803921569, 0.17254901960784313),
#  (0.984313725490196, 0.6039215686274509, 0.6),
#  (0.8901960784313725, 0.10196078431372549, 0.10980392156862745),
#  (0.9921568627450981, 0.7490196078431373, 0.43529411764705883),
#  (1.0, 0.4980392156862745, 0.0),
#  (0.792156862745098, 0.6980392156862745, 0.8392156862745098),
#  (0.41568627450980394, 0.23921568627450981, 0.6039215686274509),
#  (1.0, 1.0, 0.6),
#  (0.6941176470588235, 0.34901960784313724, 0.1568627450980392)]
